# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# %%
df = pd.read_parquet("data/jump_df.parquet")

# %%
pd.set_option("display.max_columns", None)
df.head()
# Out:
#   Metadata_Plate Metadata_Well  Metadata_Field   Metadata_broad_sample  \
# 0     BR00116991           A01               1  BRD-A86665761-001-01-1
# 1     BR00116991           A01               2  BRD-A86665761-001-01-1
# 2     BR00116991           A01               3  BRD-A86665761-001-01-1
# 3     BR00116991           A01               4  BRD-A86665761-001-01-1
# 4     BR00116991           A01               5  BRD-A86665761-001-01-1
#
#   Metadata_solvent      Metadata_Batch Metadata_PlateType  \
# 0             DMSO  2020_11_04_CPJUMP1           COMPOUND
# 1             DMSO  2020_11_04_CPJUMP1           COMPOUND
# 2             DMSO  2020_11_04_CPJUMP1           COMPOUND
# 3             DMSO  2020_11_04_CPJUMP1           COMPOUND
# 4             DMSO  2020_11_04_CPJUMP1           COMPOUND
#
#              Metadata_InChIKey   Metadata_pert_iname  Metadata_pubchem_cid  \
# 0  TZDUHAJSIBHXDL-UHFFFAOYSA-N  gabapentin-enacarbil             9883933.0
# 1  TZDUHAJSIBHXDL-UHFFFAOYSA-N  gabapentin-enacarbil             9883933.0
# 2  TZDUHAJSIBHXDL-UHFFFAOYSA-N  gabapentin-enacarbil             9883933.0
# 3  TZDUHAJSIBHXDL-UHFFFAOYSA-N  gabapentin-enacarbil             9883933.0
# 4  TZDUHAJSIBHXDL-UHFFFAOYSA-N  gabapentin-enacarbil             9883933.0
#
#   Metadata_gene Metadata_pert_type Metadata_control_type  \
# 0        CACNB4                trt                  None
# 1        CACNB4                trt                  None
# 2        CACNB4                trt                  None
# 3        CACNB4                trt                  None
# 4        CACNB4                trt                  None
#
#                             Metadata_SMILES Metadata_target  \
# 0  CC(C)C(=O)OC(C)OC(=O)NCC1(CC(O)=O)CCCCC1          CACNB4
# 1  CC(C)C(=O)OC(C)OC(=O)NCC1(CC(O)=O)CCCCC1          CACNB4
# 2  CC(C)C(=O)OC(C)OC(=O)NCC1(CC(O)=O)CCCCC1          CACNB4
# 3  CC(C)C(=O)OC(C)OC(=O)NCC1(CC(O)=O)CCCCC1          CACNB4
# 4  CC(C)C(=O)OC(C)OC(=O)NCC1(CC(O)=O)CCCCC1          CACNB4
#
#                                 Metadata_target_list Metadata_target_sequence  \
# 0  CACNA1A|CACNA1B|CACNA1C|CACNA1D|CACNA1E|CACNA1...                     None
# 1  CACNA1A|CACNA1B|CACNA1C|CACNA1D|CACNA1E|CACNA1...                     None
# 2  CACNA1A|CACNA1B|CACNA1C|CACNA1D|CACNA1E|CACNA1...                     None
# 3  CACNA1A|CACNA1B|CACNA1C|CACNA1D|CACNA1E|CACNA1...                     None
# 4  CACNA1A|CACNA1B|CACNA1C|CACNA1D|CACNA1E|CACNA1...                     None
#
#   Metadata_negcon_control_type Assay_Plate_Barcode  \
# 0                         None          BR00116991
# 1                         None          BR00116991
# 2                         None          BR00116991
# 3                         None          BR00116991
# 4                         None          BR00116991
#
#                     Plate_Map_Name  \
# 0  JUMP-Target-1_compound_platemap
# 1  JUMP-Target-1_compound_platemap
# 2  JUMP-Target-1_compound_platemap
# 3  JUMP-Target-1_compound_platemap
# 4  JUMP-Target-1_compound_platemap
#
#                                            Image_RNA  \
# 0  cpg0000-jump-pilot/source_4/images/2020_11_04_...
# 1  cpg0000-jump-pilot/source_4/images/2020_11_04_...
# 2  cpg0000-jump-pilot/source_4/images/2020_11_04_...
# 3  cpg0000-jump-pilot/source_4/images/2020_11_04_...
# 4  cpg0000-jump-pilot/source_4/images/2020_11_04_...
#
#                                             Image_ER  \
# 0  cpg0000-jump-pilot/source_4/images/2020_11_04_...
# 1  cpg0000-jump-pilot/source_4/images/2020_11_04_...
# 2  cpg0000-jump-pilot/source_4/images/2020_11_04_...
# 3  cpg0000-jump-pilot/source_4/images/2020_11_04_...
# 4  cpg0000-jump-pilot/source_4/images/2020_11_04_...
#
#                                            Image_AGP  \
# 0  cpg0000-jump-pilot/source_4/images/2020_11_04_...
# 1  cpg0000-jump-pilot/source_4/images/2020_11_04_...
# 2  cpg0000-jump-pilot/source_4/images/2020_11_04_...
# 3  cpg0000-jump-pilot/source_4/images/2020_11_04_...
# 4  cpg0000-jump-pilot/source_4/images/2020_11_04_...
#
#                                           Image_Mito  \
# 0  cpg0000-jump-pilot/source_4/images/2020_11_04_...
# 1  cpg0000-jump-pilot/source_4/images/2020_11_04_...
# 2  cpg0000-jump-pilot/source_4/images/2020_11_04_...
# 3  cpg0000-jump-pilot/source_4/images/2020_11_04_...
# 4  cpg0000-jump-pilot/source_4/images/2020_11_04_...
#
#                                            Image_DNA  \
# 0  cpg0000-jump-pilot/source_4/images/2020_11_04_...
# 1  cpg0000-jump-pilot/source_4/images/2020_11_04_...
# 2  cpg0000-jump-pilot/source_4/images/2020_11_04_...
# 3  cpg0000-jump-pilot/source_4/images/2020_11_04_...
# 4  cpg0000-jump-pilot/source_4/images/2020_11_04_...
#
#                                    Image_Brightfield Source_Dataset  \
# 0  cpg0000-jump-pilot/source_4/images/2020_11_04_...        cpg0000
# 1  cpg0000-jump-pilot/source_4/images/2020_11_04_...        cpg0000
# 2  cpg0000-jump-pilot/source_4/images/2020_11_04_...        cpg0000
# 3  cpg0000-jump-pilot/source_4/images/2020_11_04_...        cpg0000
# 4  cpg0000-jump-pilot/source_4/images/2020_11_04_...        cpg0000
#
#   Metadata_Source plate_id s3_path batch Metadata_JCP2022 source_file  \
# 0        source_4     None    None  None             None        None
# 1        source_4     None    None  None             None        None
# 2        source_4     None    None  None             None        None
# 3        source_4     None    None  None             None        None
# 4        source_4     None    None  None             None        None
#
#   Metadata_InChI Metadata_Name Metadata_Vector Metadata_Transcript  \
# 0           None          None            None                None
# 1           None          None            None                None
# 2           None          None            None                None
# 3           None          None            None                None
# 4           None          None            None                None
#
#   Metadata_Symbol_x Metadata_NCBI_Gene_ID_x Metadata_Taxon_ID  \
# 0              None                    None              None
# 1              None                    None              None
# 2              None                    None              None
# 3              None                    None              None
# 4              None                    None              None
#
#   Metadata_Gene_Description  Metadata_Prot_Match  Metadata_Insert_Length  \
# 0                      None                  NaN                     NaN
# 1                      None                  NaN                     NaN
# 2                      None                  NaN                     NaN
# 3                      None                  NaN                     NaN
# 4                      None                  NaN                     NaN
#
#    Metadata_NCBI_Gene_ID_y Metadata_Symbol_y  Metadata_Source_microscope  \
# 0                      NaN              None                         NaN
# 1                      NaN              None                         NaN
# 2                      NaN              None                         NaN
# 3                      NaN              None                         NaN
# 4                      NaN              None                         NaN
#
#   Metadata_Microscope_Name Metadata_Widefield_vs_Confocal  \
# 0                     None                           None
# 1                     None                           None
# 2                     None                           None
# 3                     None                           None
# 4                     None                           None
#
#   Metadata_Excitation_Type  Metadata_Objective_NA  \
# 0                     None                    NaN
# 1                     None                    NaN
# 2                     None                    NaN
# 3                     None                    NaN
# 4                     None                    NaN
#
#    Metadata_N_Brightfield_Planes_Min  Metadata_N_Brightfield_Planes_Max  \
# 0                                NaN                                NaN
# 1                                NaN                                NaN
# 2                                NaN                                NaN
# 3                                NaN                                NaN
# 4                                NaN                                NaN
#
#    Metadata_Distance_Between_Z_Microns  Metadata_Sites_Per_Well  \
# 0                                  NaN                      NaN
# 1                                  NaN                      NaN
# 2                                  NaN                      NaN
# 3                                  NaN                      NaN
# 4                                  NaN                      NaN
#
#   Metadata_Filter_Configuration  Metadata_Pixel_Size_Microns  \
# 0                          None                          NaN
# 1                          None                          NaN
# 2                          None                          NaN
# 3                          None                          NaN
# 4                          None                          NaN
#
#    Metadata_Excitation_Low_DNA  Metadata_Excitation_Low_ER  \
# 0                          NaN                         NaN
# 1                          NaN                         NaN
# 2                          NaN                         NaN
# 3                          NaN                         NaN
# 4                          NaN                         NaN
#
#    Metadata_Excitation_Low_RNA  Metadata_Excitation_Low_AGP  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
#
#    Metadata_Excitation_Low_Mito  Metadata_Excitation_High_DNA  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#    Metadata_Excitation_High_ER  Metadata_Excitation_High_RNA  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
# 2                          NaN                           NaN
# 3                          NaN                           NaN
# 4                          NaN                           NaN
#
#    Metadata_Excitation_High_AGP  Metadata_Excitation_High_Mito  \
# 0                           NaN                            NaN
# 1                           NaN                            NaN
# 2                           NaN                            NaN
# 3                           NaN                            NaN
# 4                           NaN                            NaN
#
#    Metadata_Emission_Low_DNA  Metadata_Emission_Low_ER  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                        NaN                       NaN
# 3                        NaN                       NaN
# 4                        NaN                       NaN
#
#    Metadata_Emission_Low_RNA  Metadata_Emission_Low_AGP  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
#
#    Metadata_Emission_Low_Mito  Metadata_Emission_High_DNA  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#    Metadata_Emission_High_ER  Metadata_Emission_High_RNA  \
# 0                        NaN                         NaN
# 1                        NaN                         NaN
# 2                        NaN                         NaN
# 3                        NaN                         NaN
# 4                        NaN                         NaN
#
#    Metadata_Emission_High_AGP  Metadata_Emission_High_Mito  \
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                         NaN                          NaN
#
#   Metadata_FPBase_Config
# 0                   None
# 1                   None
# 2                   None
# 3                   None
# 4                   None

# %%
print(f"Total number of rows: {len(df):,}")
print(f"Memory usage: {df.memory_usage().sum() / 1024**2:.1f} MB")
print("\nColumns:", df.columns.tolist())
# Out:
# Total number of rows: 7,708,265
# Memory usage: 4528.3 MB
#
# Columns: ['Metadata_Plate', 'Metadata_Well', 'Metadata_Field', 'Metadata_broad_sample', 'Metadata_solvent', 'Metadata_Batch', 'Metadata_PlateType', 'Metadata_InChIKey', 'Metadata_pert_iname', 'Metadata_pubchem_cid', 'Metadata_gene', 'Metadata_pert_type', 'Metadata_control_type', 'Metadata_SMILES', 'Metadata_target', 'Metadata_target_list', 'Metadata_target_sequence', 'Metadata_negcon_control_type', 'Assay_Plate_Barcode', 'Plate_Map_Name', 'Image_RNA', 'Image_ER', 'Image_AGP', 'Image_Mito', 'Image_DNA', 'Image_Brightfield', 'Source_Dataset', 'Metadata_Source', 'plate_id', 's3_path', 'batch', 'Metadata_JCP2022', 'source_file', 'Metadata_InChI', 'Metadata_Name', 'Metadata_Vector', 'Metadata_Transcript', 'Metadata_Symbol_x', 'Metadata_NCBI_Gene_ID_x', 'Metadata_Taxon_ID', 'Metadata_Gene_Description', 'Metadata_Prot_Match', 'Metadata_Insert_Length', 'Metadata_NCBI_Gene_ID_y', 'Metadata_Symbol_y', 'Metadata_Source_microscope', 'Metadata_Microscope_Name', 'Metadata_Widefield_vs_Confocal', 'Metadata_Excitation_Type', 'Metadata_Objective_NA', 'Metadata_N_Brightfield_Planes_Min', 'Metadata_N_Brightfield_Planes_Max', 'Metadata_Distance_Between_Z_Microns', 'Metadata_Sites_Per_Well', 'Metadata_Filter_Configuration', 'Metadata_Pixel_Size_Microns', 'Metadata_Excitation_Low_DNA', 'Metadata_Excitation_Low_ER', 'Metadata_Excitation_Low_RNA', 'Metadata_Excitation_Low_AGP', 'Metadata_Excitation_Low_Mito', 'Metadata_Excitation_High_DNA', 'Metadata_Excitation_High_ER', 'Metadata_Excitation_High_RNA', 'Metadata_Excitation_High_AGP', 'Metadata_Excitation_High_Mito', 'Metadata_Emission_Low_DNA', 'Metadata_Emission_Low_ER', 'Metadata_Emission_Low_RNA', 'Metadata_Emission_Low_AGP', 'Metadata_Emission_Low_Mito', 'Metadata_Emission_High_DNA', 'Metadata_Emission_High_ER', 'Metadata_Emission_High_RNA', 'Metadata_Emission_High_AGP', 'Metadata_Emission_High_Mito', 'Metadata_FPBase_Config']
